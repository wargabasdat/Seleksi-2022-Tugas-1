# %%
import pandas as pd
df = pd.read_csv(r'.\wardah.csv')

# %%
df
# Out:
#    category                                              image  \
# 0   MAKE UP  https://wardah-mainsite.s3-ap-southeast-1.amaz...
# 1   MAKE UP  https://wardah-mainsite.s3-ap-southeast-1.amaz...
# 2   MAKE UP  https://wardah-mainsite.s3-ap-southeast-1.amaz...
# 3   MAKE UP  https://wardah-mainsite.s3-ap-southeast-1.amaz...
# 4   MAKE UP  https://wardah-mainsite.s3-ap-southeast-1.amaz...
# ..      ...                                                ...
# 73  MAKE UP  https://wardah-mainsite.s3-ap-southeast-1.amaz...
# 74  MAKE UP  https://wardah-mainsite.s3-ap-southeast-1.amaz...
# 75  MAKE UP  https://wardah-mainsite.s3-ap-southeast-1.amaz...
# 76  MAKE UP  https://wardah-mainsite.s3-ap-southeast-1.amaz...
# 77  MAKE UP  https://wardah-mainsite.s3-ap-southeast-1.amaz...
#
#       sub_category                                       product_name   price  \
# 0         COLORFIT  NEW! Wardah Bundle Colorfit Lip Paint - Dazzli...   99180
# 1         COLORFIT  NEW! Wardah Bundle Colorfit Lip Paint - Royal ...  179580
# 2   COLORFIT, LIPS   Colorfit Last All Day Lip Paint Around the World   62985
# 3         COLORFIT                      Colorfit Perfect Glow Cushion  101650
# 4             LIPS                           Everyday! Matte Lip Shot   46000
# ..             ...                                                ...     ...
# 73            LIPS                             Intense Matte Lipstick   49500
# 74            LIPS                           Exclusive Moist Lipstick   21500
# 75            LIPS                           Exclusive Matte Lipstick   21500
# 76            FACE                                 Exclusive Blush On   62500
# 77            LIPS                          Exclusive Matte Lip Cream   59850
#
#                                                 about  \
# 0   NEW! Wardah Special Bundle Colorfit Lip Paint ...
# 1   NEW! Wardah Special Bundle Colorfit Lip Paint ...
# 2   Colorfit Last All Day Lip Paint Around the Wor...
# 3   Colorfit Perfect Glow Cushion merupakan base m...
# 4   Quick set lip cream dengan hasil matte yang di...
# ..                                                ...
# 73  Matte and moist in a minute! True matte finish...
# 74  Lipstick Moist dengan kilap alami yang memberi...
# 75  Matte Lipstik dengan hasil yang lembut dan nya...
# 76  Wardah Exclusive Blush on yang tersedia dalam ...
# 77  The Perfect Color Intensity for an Unforgettab...
#
#                                                how_to  \
# 0   Ready-to-go travel pack make up to experience ...
# 1   Ready-to-go travel pack make up to experience ...
# 2   Aplikasikan lipstik pada bibir., Gunakan aplik...
# 3   Ambil bulk menggunakan puff yang disediakan de...
# 4   Aplikasikan Everyday! Matte Lip Shot dengan ap...
# ..                                                ...
# 73  1. Putar lipstik keluar maksimal ¼ bagian (jan...
# 74  1. Putar lipstik keluar maksimal ¼ bagian (jan...
# 75  1. Putar lipstik keluar maksimal ¼ bagian (jan...
# 76  1. Aplikasikan blush pada pipimu, 2. Sapukan d...
# 77  Gunakan Wardah Lip Balm atau Lipgloss sebelum ...
#
#                                           ingredients            variant/0  \
# 0                                                 NaN                  NaN
# 1                                                 NaN                  NaN
# 2   Isododecane, Bis-Hydroxylauryl Dimethicone/IPD...  00 Alluring Jakarta
# 3     SkinMatch Technology\r\nGlow Perfecting Pigment    11C 11C Pink Fair
# 4                                                 NaN              01 #fyp
# ..                                                ...                  ...
# 73                                                NaN   01 Socialite Peach
# 74                                                NaN        20 Pink Pearl
# 75                                                NaN              01 Pink
# 76                                                NaN            Rosy Pink
# 77  Cyclopentasiloxane, Isododecane, Trisiloxane, ...        01 Red-dicted
#
#              variant/1  ...           variant/9          variant/10  \
# 0                  NaN  ...                 NaN                 NaN
# 1                  NaN  ...                 NaN                 NaN
# 2         13 Dubai Lux  ...                 NaN                 NaN
# 3   23W 23W Warm Ivory  ...                 NaN                 NaN
# 4        02 #throwback  ...                 NaN                 NaN
# ..                 ...  ...                 ...                 ...
# 73    02 Blushing Nude  ...  10 Miss Terracotta       11 Choco Town
# 74     21 Pink Orchid   ...     41 Charming Red  43 Magnificent Red
# 75          02 Magenta  ...      16 Summer Pink    17 Gorgeous Pink
# 76         Coral Peach  ...                 NaN                 NaN
# 77    02 Fuschionately  ...     10 Berry Pretty       11 Oh So Nude
#
#           variant/11        variant/12        variant/13        variant/14  \
# 0                NaN               NaN               NaN               NaN
# 1                NaN               NaN               NaN               NaN
# 2                NaN               NaN               NaN               NaN
# 3                NaN               NaN               NaN               NaN
# 4                NaN               NaN               NaN               NaN
# ..               ...               ...               ...               ...
# 73  12 Lady Burgundy  13 Yummy Brownie  14 Active Cerise     15 Out of Red
# 74   46 Chic Magenta               NaN               NaN               NaN
# 75      18 Rosy Pink               NaN               NaN               NaN
# 76               NaN               NaN               NaN               NaN
# 77     12 Plum It Up    13 Fruit Punch   14 My Honey Bee  15 Pinky Plumise
#
#       variant/15     variant/16          variant/17 variant/18
# 0            NaN            NaN                 NaN        NaN
# 1            NaN            NaN                 NaN        NaN
# 2            NaN            NaN                 NaN        NaN
# 3            NaN            NaN                 NaN        NaN
# 4            NaN            NaN                 NaN        NaN
# ..           ...            ...                 ...        ...
# 73  16 Pecan Pie            NaN                 NaN        NaN
# 74           NaN            NaN                 NaN        NaN
# 75           NaN            NaN                 NaN        NaN
# 76           NaN            NaN                 NaN        NaN
# 77  16 Heartbeet  17 Rosy Cheek  18 Saturdate Night        NaN
#
# [78 rows x 27 columns]

# %% [markdown]
# 1. Visualisasi Data untuk Jumlah Item di Setiap Sub Kategori

# %%
df['sub_category'].value_counts().plot(kind = "barh")
# Out:
# <AxesSubplot:>

# %% [markdown]
# 2. Visualisasi Data untuk Menampilkan 5 Produk Termahal

# %%
largest5 = df.nlargest(n=5, columns = ['price'])
largest5.plot.area(x="product_name",y="price",figsize=(18,7))
# Out:
# <AxesSubplot:xlabel='product_name'>

# %% [markdown]
# 3. Visualisasi Data untuk Menampilkan 5 Produk Termurah

# %%
smallest5 = df.nsmallest(n=5, columns = ['price'])
smallest5.plot.line(x="product_name",y="price",figsize=(18,7))
# Out:
# <AxesSubplot:xlabel='product_name'>
